# %% [markdown]
# # Train v5 — Feature Engineering + Multi-Seed Ensemble
#
# Changes from v4:
# 1. **Time-index features**: ts_log, ts_mod (5/21/63), ts_sin/cos (252, 100)
# 2. **Industry-neutral features**: per-horizon top features normalized by `code` and by `sub_category` (both per `ts_index`)
# 3. **Multi-seed ensemble**: 6 seeds per horizon, all models kept for inspection
# 4. **Memory-efficient**: load & engineer features per-horizon

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent.parent
sys.path.append(str(PROJECT_ROOT))

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import gc
from src.score import weighted_rmse_score as score
import time

# %% [markdown]
# ## Config

# %%
TRAIN_PATH = PROJECT_ROOT / "data" / "train.parquet"
TEST_PATH  = PROJECT_ROOT / "data" / "test.parquet"
MODEL_DIR  = PROJECT_ROOT / "models"
SUB_DIR    = PROJECT_ROOT / "submissions"

HORIZONS = [1, 3, 10, 25]
SEEDS    = [2004, 12, 24, 2003, 2, 5]
VERSION  = "v5"
ZERO_CODES = ['MLAAMU3K', 'EP12UF2K', '1HEMHZK2', 'SJZP0OVU', '83EG83KQ']

SPLIT_INDEX = 3500

# Per-horizon top features for industry-neutral normalization
NEUTRAL_FEATURES = {
    1:  ['feature_al', 'feature_s',  'feature_ce', 'feature_by',
         'feature_y',  'feature_t',  'feature_cf', 'feature_x', 'feature_cb'],
    3:  ['feature_ce', 'feature_cg', 'feature_v',  'feature_cf',
         'feature_y',  'feature_bg', 'feature_al', 'feature_aq', 'feature_z'],
    10: ['feature_v',  'feature_cg', 'feature_ce', 'feature_bg',
         'feature_cf', 'feature_u',  'feature_l',  'feature_z', 'feature_al'],
    25: ['feature_v',  'feature_bg', 'feature_l',  'feature_cg',
         'feature_cf', 'feature_m',  'feature_ce', 'feature_z', 'feature_aq'],
}

BASE_PARAMS = {
    'objective': 'regression',
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'num_leaves': 80,
    'min_child_samples': 200,
    'lambda_l2': 10,
    'learning_rate': 0.01,
    'bagging_fraction': 0.7,
    'bagging_freq': 5,
    'feature_fraction': 0.8,
    'verbosity': -1,
}

NUM_BOOST_ROUND = 4200
EARLY_STOPPING  = 200

print(f'Horizons: {HORIZONS}')
print(f'Seeds:    {SEEDS}')
print(f'Split:    ts_index <= {SPLIT_INDEX} (train) | > {SPLIT_INDEX} (val)')
# Out:
# Horizons: [1, 3, 10, 25]
# Seeds:    [2004, 12, 24, 2003, 2, 5]
# Split:    ts_index <= 3500 (train) | > 3500 (val)

# %% [markdown]
# ## Feature Engineering Functions

# %%
def add_time_features(df):
    """Add time-index derived features."""
    ts = df['ts_index']
    df['ts_log']     = np.log1p(ts)
    df['ts_mod_7']   = ts % 5
    df['ts_mod_30']  = ts % 21
    df['ts_mod_90']  = ts % 63
    df['ts_sin']     = np.sin(2 * np.pi * ts / 252)
    df['ts_cos']     = np.cos(2 * np.pi * ts / 252)
    df['ts_sin_100'] = np.sin(2 * np.pi * ts / 100)
    df['ts_cos_100'] = np.cos(2 * np.pi * ts / 100)
    return df


def add_industry_neutral(df, horizon):
    """Add industry-neutral features: normalize by code and by sub_category, both per ts_index."""
    feats = NEUTRAL_FEATURES[horizon]
    
    for group_col, suffix in [('code', '_neut_code'), ('sub_category', '_neut_subcat')]:
        # Compute group mean and std per (group_col, ts_index)
        group_stats = df.groupby([group_col, 'ts_index'])[feats].agg(['mean', 'std'])
        # Flatten multi-level columns: (feature, mean) -> feature_mean, etc.
        group_stats.columns = [f'{f}_{s}' for f, s in group_stats.columns]
        group_stats = group_stats.reset_index()
        
        # Merge back
        df = df.merge(group_stats, on=[group_col, 'ts_index'], how='left')
        
        # Compute normalized features
        for f in feats:
            mean_col = f'{f}_mean'
            std_col  = f'{f}_std'
            new_col  = f'{f}{suffix}'
            df[new_col] = (df[f] - df[mean_col]) / (df[std_col] + 1e-8)
            # Drop temp columns
            df.drop(columns=[mean_col, std_col], inplace=True)
    
    return df


def create_features(df, horizon):
    """Full feature engineering pipeline for a single horizon."""
    df = add_time_features(df)
    df = add_industry_neutral(df, horizon)
    return df


def set_cat(df, cat_features):
    for feat in cat_features:
        if feat in df.columns:
            df[feat] = df[feat].astype('category')
    return df


print('Feature engineering functions defined.')
# Out:
# Feature engineering functions defined.

# %% [markdown]
# ## Train: Per-Horizon × Multi-Seed
#
# For each horizon:
# 1. Load & filter to horizon
# 2. Create features (time + industry-neutral)
# 3. Split train/val on ts_index
# 4. Train 6 seeds, keep all models

# %%
CAT_FEATURES = ['code', 'sub_category', 'horizon']
EXCLUDE_COLS = ['id', 'sub_code', 'ts_index', 'weight', 'y_target']

# Storage for all models and val predictions
all_models = {}       # (horizon, seed) -> booster
all_importances = {}  # horizon -> importance DataFrame (averaged across seeds)
val_preds_all = {}    # horizon -> DataFrame with index, per-seed preds, and ensemble
val_meta_all  = {}    # horizon -> (y_target, weight, code) for scoring

for h in HORIZONS:
    t0 = time.time()
    print(f"\n{'='*70}")
    print(f"  HORIZON = {h}")
    print(f"{'='*70}")

    # ── 1. Load & engineer features ──
    print(f"  Loading and engineering features...")
    df_h = create_features(
        pd.read_parquet(TRAIN_PATH).query(f"horizon == {h}").reset_index(drop=True),
        horizon=h
    )

    # ── 2. Identify feature columns ──
    features = [c for c in df_h.columns if c not in EXCLUDE_COLS]
    df_h = set_cat(df_h, CAT_FEATURES)
    print(f"  Total features: {len(features)}")

    # ── 3. Train/Val split ──
    train_mask = df_h['ts_index'] <= SPLIT_INDEX
    val_mask   = ~train_mask
    h_train = df_h[train_mask]
    h_val   = df_h[val_mask]
    print(f"  Train: {len(h_train):,} | Val: {len(h_val):,}")

    # Store val metadata for scoring
    val_meta_all[h] = {
        'y_target': h_val['y_target'].values,
        'weight':   h_val['weight'].values,
        'code':     h_val['code'].values,
        'index':    h_val.index.values,
    }

    # ── 4. LightGBM Datasets (shared across seeds) ──
    dtrain = lgb.Dataset(
        h_train[features], label=h_train['y_target'], weight=h_train['weight'],
        categorical_feature=CAT_FEATURES, free_raw_data=False
    )
    dval = lgb.Dataset(
        h_val[features], label=h_val['y_target'], weight=h_val['weight'],
        categorical_feature=CAT_FEATURES, reference=dtrain, free_raw_data=False
    )
    del h_train, h_val, df_h
    gc.collect()
    # ── 5. Multi-seed training ──
    seed_importances = []
    seed_val_preds   = {}

    for seed in SEEDS:
        params = {**BASE_PARAMS, 'seed': seed}
        print(f"\n  --- Seed {seed} ---")

        model = lgb.train(
            params, dtrain,
            valid_sets=[dtrain, dval],
            valid_names=['train', 'val'],
            num_boost_round=NUM_BOOST_ROUND,
            callbacks=[
                lgb.early_stopping(stopping_rounds=EARLY_STOPPING),
                lgb.log_evaluation(period=300)
            ]
        )
        all_models[(h, seed)] = model

        # Save model
        model_path = MODEL_DIR / f"lgb_model_{VERSION}_horizon{h}_seed{seed}.txt"
        model.save_model(model_path, num_iteration=model.best_iteration)
        print(f"    Saved -> {model_path}  (best iter: {model.best_iteration})")

        # Val predictions
        preds = model.predict(h_val[features], num_iteration=model.best_iteration)
        seed_val_preds[seed] = preds

        # Feature importance
        imp = pd.Series(
            model.feature_importance(importance_type='gain'),
            index=features
        )
        seed_importances.append(imp)

    # ── 6. Ensemble val predictions (average across seeds) ──
    val_preds_df = pd.DataFrame(seed_val_preds)
    val_preds_df['ensemble'] = val_preds_df.mean(axis=1)
    val_preds_all[h] = val_preds_df

    # ── 7. Average feature importance ──
    avg_imp = pd.concat(seed_importances, axis=1).mean(axis=1).sort_values(ascending=False)
    all_importances[h] = avg_imp
    print(f"\n  Top-10 features (horizon={h}, averaged over {len(SEEDS)} seeds):")
    print(avg_imp.head(10).to_frame('importance').to_string())

    # ── 8. Free memory ──
    del df_h, h_train, h_val, dtrain, dval
    gc.collect()
    print(f"\n  Horizon {h} done in {time.time()-t0:.1f}s")
# Out:
# ======================================================================
#   HORIZON = 1
# ======================================================================
#   Loading and engineering features...
#   Total features: 115
#   Train: 1,351,193 | Val: 43,460
#
#   --- Seed 2004 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.000965514	val's rmse: 0.00113621
# [600]	train's rmse: 0.000955234	val's rmse: 0.00113528
# [900]	train's rmse: 0.000947184	val's rmse: 0.00113508
# Early stopping, best iteration is:
# [893]	train's rmse: 0.000947364	val's rmse: 0.00113497
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h1_seed2004.txt  (best iter: 893)
#
#   --- Seed 12 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.000965441	val's rmse: 0.00113617
# Early stopping, best iteration is:
# [227]	train's rmse: 0.000968605	val's rmse: 0.00113584
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h1_seed12.txt  (best iter: 227)
#
#   --- Seed 24 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.000965606	val's rmse: 0.00113584
# [600]	train's rmse: 0.000955786	val's rmse: 0.00113563
# Early stopping, best iteration is:
# [465]	train's rmse: 0.000959883	val's rmse: 0.00113532
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h1_seed24.txt  (best iter: 465)
#
#   --- Seed 2003 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.000965713	val's rmse: 0.00113551
# Early stopping, best iteration is:
# [174]	train's rmse: 0.000971366	val's rmse: 0.00113538
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h1_seed2003.txt  (best iter: 174)
#
#   --- Seed 2 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00096558	val's rmse: 0.00113606
# Early stopping, best iteration is:
# [234]	train's rmse: 0.000968602	val's rmse: 0.00113592
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h1_seed2.txt  (best iter: 234)
#
#   --- Seed 5 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.000965357	val's rmse: 0.0011353
# Early stopping, best iteration is:
# [348]	train's rmse: 0.000963394	val's rmse: 0.001135
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h1_seed5.txt  (best iter: 348)
#
#   Top-10 features (horizon=1, averaged over 6 seeds):
#                           importance
# feature_al              1.741367e+06
# sub_category            1.422072e+06
# feature_by              1.153279e+06
# feature_s               9.050734e+05
# ts_cos_100              8.815733e+05
# feature_al_neut_subcat  8.247173e+05
# feature_y               6.850256e+05
# ts_sin_100              6.744710e+05
# ts_cos                  6.710847e+05
# feature_by_neut_subcat  6.636704e+05
#
#   Horizon 1 done in 1247.5s
#
# ======================================================================
#   HORIZON = 3
# ======================================================================
#   Loading and engineering features...
#   Total features: 115
#   Train: 1,342,793 | Val: 43,023
#
#   --- Seed 2004 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00119462	val's rmse: 0.00182008
# [600]	train's rmse: 0.00117652	val's rmse: 0.00181787
# [900]	train's rmse: 0.001163	val's rmse: 0.00182377
# Early stopping, best iteration is:
# [717]	train's rmse: 0.00117085	val's rmse: 0.00181737
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h3_seed2004.txt  (best iter: 717)
#
#   --- Seed 12 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00119541	val's rmse: 0.00182044
# [600]	train's rmse: 0.00117688	val's rmse: 0.00181893
# Early stopping, best iteration is:
# [572]	train's rmse: 0.00117843	val's rmse: 0.00181815
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h3_seed12.txt  (best iter: 572)
#
#   --- Seed 24 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00119497	val's rmse: 0.00181986
# [600]	train's rmse: 0.00117717	val's rmse: 0.00181676
# [900]	train's rmse: 0.00116314	val's rmse: 0.00181617
# [1200]	train's rmse: 0.00115054	val's rmse: 0.00181449
# Early stopping, best iteration is:
# [1248]	train's rmse: 0.00114861	val's rmse: 0.0018143
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h3_seed24.txt  (best iter: 1248)
#
#   --- Seed 2003 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.0011945	val's rmse: 0.00182004
# Early stopping, best iteration is:
# [270]	train's rmse: 0.00119696	val's rmse: 0.00181831
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h3_seed2003.txt  (best iter: 270)
#
#   --- Seed 2 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.0011941	val's rmse: 0.00182039
# [600]	train's rmse: 0.00117509	val's rmse: 0.00181758
# [900]	train's rmse: 0.00116094	val's rmse: 0.00181634
# [1200]	train's rmse: 0.00114881	val's rmse: 0.00181587
# [1500]	train's rmse: 0.00113821	val's rmse: 0.00181581
# [1800]	train's rmse: 0.00112879	val's rmse: 0.00181596
# Early stopping, best iteration is:
# [1624]	train's rmse: 0.00113417	val's rmse: 0.00181546
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h3_seed2.txt  (best iter: 1624)
#
#   --- Seed 5 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00119506	val's rmse: 0.00182068
# [600]	train's rmse: 0.00117575	val's rmse: 0.00181792
# [900]	train's rmse: 0.00116084	val's rmse: 0.00181658
# Early stopping, best iteration is:
# [888]	train's rmse: 0.00116131	val's rmse: 0.00181642
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h3_seed5.txt  (best iter: 888)
#
#   Top-10 features (horizon=3, averaged over 6 seeds):
#                 importance
# sub_category  8.621777e+06
# ts_cos        6.713056e+06
# ts_sin        6.688945e+06
# ts_sin_100    6.632391e+06
# ts_log        6.422109e+06
# ts_cos_100    6.083653e+06
# feature_ce    4.865689e+06
# feature_cg    4.863250e+06
# ts_mod_90     4.627868e+06
# feature_cf    4.543626e+06
#
#   Horizon 3 done in 1988.0s
#
# ======================================================================
#   HORIZON = 10
# ======================================================================
#   Loading and engineering features...
#   Total features: 115
#   Train: 1,296,269 | Val: 40,967
#
#   --- Seed 2004 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00257209	val's rmse: 0.00269769
# [600]	train's rmse: 0.00249788	val's rmse: 0.00268575
# [900]	train's rmse: 0.00244321	val's rmse: 0.00269029
# Early stopping, best iteration is:
# [796]	train's rmse: 0.00246094	val's rmse: 0.00268282
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h10_seed2004.txt  (best iter: 796)
#
#   --- Seed 12 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00257361	val's rmse: 0.00269303
# [600]	train's rmse: 0.00249787	val's rmse: 0.00268705
# Early stopping, best iteration is:
# [680]	train's rmse: 0.00248232	val's rmse: 0.00268422
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h10_seed12.txt  (best iter: 680)
#
#   --- Seed 24 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.0025738	val's rmse: 0.00270398
# [600]	train's rmse: 0.00249697	val's rmse: 0.00269056
# [900]	train's rmse: 0.00244121	val's rmse: 0.00268896
# Early stopping, best iteration is:
# [814]	train's rmse: 0.00245514	val's rmse: 0.00268446
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h10_seed24.txt  (best iter: 814)
#
#   --- Seed 2003 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00257067	val's rmse: 0.00273515
# Early stopping, best iteration is:
# [213]	train's rmse: 0.00260252	val's rmse: 0.00269807
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h10_seed2003.txt  (best iter: 213)
#
#   --- Seed 2 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00257378	val's rmse: 0.00269512
# [600]	train's rmse: 0.00249752	val's rmse: 0.00271473
# Early stopping, best iteration is:
# [487]	train's rmse: 0.00252365	val's rmse: 0.00268955
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h10_seed2.txt  (best iter: 487)
#
#   --- Seed 5 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00257534	val's rmse: 0.00269342
# [600]	train's rmse: 0.00249848	val's rmse: 0.0026824
# Early stopping, best iteration is:
# [647]	train's rmse: 0.00248895	val's rmse: 0.00268065
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h10_seed5.txt  (best iter: 647)
#
#   Top-10 features (horizon=10, averaged over 6 seeds):
#                 importance
# ts_log        5.387059e+07
# ts_sin        3.322803e+07
# sub_category  2.930824e+07
# ts_cos        2.875211e+07
# feature_v     2.616244e+07
# feature_cg    2.386008e+07
# feature_cf    2.322927e+07
# ts_sin_100    2.279207e+07
# feature_u     2.104805e+07
# ts_cos_100    2.100943e+07
#
#   Horizon 10 done in 1515.0s
#
# ======================================================================
#   HORIZON = 25
# ======================================================================
#   Loading and engineering features...
#   Total features: 115
#   Train: 1,181,897 | Val: 37,812
#
#   --- Seed 2004 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00334752	val's rmse: 0.00292129
# Early stopping, best iteration is:
# [383]	train's rmse: 0.00330103	val's rmse: 0.00291521
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h25_seed2004.txt  (best iter: 383)
#
#   --- Seed 12 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.0033484	val's rmse: 0.00293426
# [600]	train's rmse: 0.00319525	val's rmse: 0.00292547
# Early stopping, best iteration is:
# [516]	train's rmse: 0.00323141	val's rmse: 0.0029154
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h25_seed12.txt  (best iter: 516)
#
#   --- Seed 24 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00334483	val's rmse: 0.00292988
# [600]	train's rmse: 0.00319592	val's rmse: 0.00291313
# [900]	train's rmse: 0.00309853	val's rmse: 0.00291131
# Early stopping, best iteration is:
# [762]	train's rmse: 0.00313959	val's rmse: 0.00290781
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h25_seed24.txt  (best iter: 762)
#
#   --- Seed 2003 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00334035	val's rmse: 0.00292506
# [600]	train's rmse: 0.00319438	val's rmse: 0.00290776
# [900]	train's rmse: 0.00309602	val's rmse: 0.00290097
# Early stopping, best iteration is:
# [939]	train's rmse: 0.00308566	val's rmse: 0.00289893
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h25_seed2003.txt  (best iter: 939)
#
#   --- Seed 2 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.00334581	val's rmse: 0.00292236
# [600]	train's rmse: 0.00320424	val's rmse: 0.00290383
# [900]	train's rmse: 0.00308971	val's rmse: 0.00291849
# Early stopping, best iteration is:
# [709]	train's rmse: 0.00315878	val's rmse: 0.0028987
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h25_seed2.txt  (best iter: 709)
#
#   --- Seed 5 ---
# Training until validation scores don't improve for 200 rounds
# [300]	train's rmse: 0.0033445	val's rmse: 0.0029253
# [600]	train's rmse: 0.00319633	val's rmse: 0.00290622
# [900]	train's rmse: 0.00309784	val's rmse: 0.00289856
# Early stopping, best iteration is:
# [896]	train's rmse: 0.00309874	val's rmse: 0.00289835
#     Saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_v5_h25_seed5.txt  (best iter: 896)
#
#   Top-10 features (horizon=25, averaged over 6 seeds):
#                           importance
# ts_log                  2.210725e+08
# sub_category            1.167572e+08
# feature_v               1.070598e+08
# ts_cos                  8.455958e+07
# ts_sin                  7.735042e+07
# feature_cg              7.604380e+07
# feature_cf              6.665304e+07
# feature_l               5.694100e+07
# feature_bg              5.450987e+07
# feature_cg_neut_subcat  4.818224e+07
#
#   Horizon 25 done in 1446.6s

# %% [markdown]
# ## Validation Scoring
# Per-seed, per-horizon, and overall ensemble scores.

# %%
print('='*70)
print('  VALIDATION SCORES')
print('='*70)

# ── Per-seed per-horizon scores ──
for h in HORIZONS:
    meta = val_meta_all[h]
    y_true = meta['y_target']
    w      = meta['weight']
    codes  = meta['code']
    zero_mask = np.isin(codes, ZERO_CODES)

    print(f"\n  Horizon {h:>2d}  (zero-coded rows: {zero_mask.sum():,})")
    for seed in SEEDS:
        preds = val_preds_all[h][seed].values.copy()
        preds[zero_mask] = 0.0
        s = score(y_true, preds, w)
        print(f"    Seed {seed:>5d}: {s:.4f}")

    # Ensemble
    ens_preds = val_preds_all[h]['ensemble'].values.copy()
    ens_preds[zero_mask] = 0.0
    ens_score = score(y_true, ens_preds, w)
    print(f"    Ensemble:  {ens_score:.4f}")

# ── Overall ensemble score ──
print(f"\n{'='*70}")
all_y = np.concatenate([val_meta_all[h]['y_target'] for h in HORIZONS])
all_w = np.concatenate([val_meta_all[h]['weight'] for h in HORIZONS])
all_p = []
for h in HORIZONS:
    meta = val_meta_all[h]
    ens = val_preds_all[h]['ensemble'].values.copy()
    zero_mask = np.isin(meta['code'], ZERO_CODES)
    ens[zero_mask] = 0.0
    all_p.append(ens)
all_p = np.concatenate(all_p)

overall = score(all_y, all_p, all_w)
print(f"  Overall Ensemble Val Score: {overall:.4f}")
print('='*70)
# Out:
# ======================================================================
#   VALIDATION SCORES
# ======================================================================
#
#   Horizon  1  (zero-coded rows: 7,675)
#     Seed  2004: 0.0567
#     Seed    12: 0.0517
#     Seed    24: 0.0551
#     Seed  2003: 0.0602
#     Seed     2: 0.0507
#     Seed     5: 0.0556
#     Ensemble:  0.0572
#
#   Horizon  3  (zero-coded rows: 7,618)
#     Seed  2004: 0.1127
#     Seed    12: 0.1171
#     Seed    24: 0.1247
#     Seed  2003: 0.1056
#     Seed     2: 0.1249
#     Seed     5: 0.1168
#     Ensemble:  0.1191
#
#   Horizon 10  (zero-coded rows: 7,238)
#     Seed  2004: 0.2086
#     Seed    12: 0.2049
#     Seed    24: 0.2034
#     Seed  2003: 0.1801
#     Seed     2: 0.1927
#     Seed     5: 0.2042
#     Ensemble:  0.2014
#
#   Horizon 25  (zero-coded rows: 6,609)
#     Seed  2004: 0.2372
#     Seed    12: 0.2401
#     Seed    24: 0.2490
#     Seed  2003: 0.2492
#     Seed     2: 0.2533
#     Seed     5: 0.2433
#     Ensemble:  0.2480
#
# ======================================================================
#   Overall Ensemble Val Score: 0.2131
# ======================================================================

# %% [markdown]
# ## Test Predictions
# For each horizon: load test, create features, predict with all seeds, average.

# %%
test_preds_parts = []  # list of DataFrames with (id, prediction)

for h in HORIZONS:
    t0 = time.time()
    print(f"\n  Predicting horizon {h}...")

    # Load & engineer
    df_test_h = create_features(
        pd.read_parquet(TEST_PATH).query(f"horizon == {h}").reset_index(drop=True),
        horizon=h
    )
    features = [c for c in df_test_h.columns if c not in EXCLUDE_COLS]
    df_test_h = set_cat(df_test_h, CAT_FEATURES)

    # Predict with each seed
    preds_accum = np.zeros(len(df_test_h), dtype=np.float64)
    for seed in SEEDS:
        model = all_models[(h, seed)]
        preds_accum += model.predict(df_test_h[features], num_iteration=model.best_iteration)
    preds_accum /= len(SEEDS)

    # Zero-code override
    zero_mask = df_test_h['code'].isin(ZERO_CODES)
    preds_accum[zero_mask] = 0.0

    test_preds_parts.append(pd.DataFrame({
        'id': df_test_h['id'].values,
        'prediction': preds_accum
    }))

    print(f"    Horizon {h:>2d}: {len(df_test_h):,} rows, "
          f"zero-coded: {zero_mask.sum():,}  ({time.time()-t0:.1f}s)")

    del df_test_h
    gc.collect()

# Combine
prediction_df = pd.concat(test_preds_parts, ignore_index=True)
assert prediction_df['prediction'].isna().sum() == 0, 'NaN in predictions!'
print(f"\n  Total test predictions: {len(prediction_df):,}")
prediction_df.head()
# Out:
#   Predicting horizon 1...
#     Horizon  1: 379,617 rows, zero-coded: 69,005  (34.7s)
#
#   Predicting horizon 3...
#     Horizon  3: 376,558 rows, zero-coded: 68,523  (91.8s)
#
#   Predicting horizon 10...
#     Horizon 10: 362,057 rows, zero-coded: 65,675  (53.3s)
#
#   Predicting horizon 25...
#     Horizon 25: 328,875 rows, zero-coded: 59,033  (59.0s)
#
#   Total test predictions: 1,447,107
#                                       id  prediction
# 0  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3647   -0.010542
# 1  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3648   -0.011377
# 2  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3649   -0.008052
# 3  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3650   -0.010372
# 4  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3651   -0.007756

# %% [markdown]
# ## Save Submission

# %%
sub_path = f"{SUB_DIR}/submission_v5.csv"
prediction_df.to_csv(sub_path, index=False)
print(f"Submission saved -> {sub_path}")
prediction_df.info()
prediction_df.head()
# Out:
# Submission saved -> /home/lingod/kaggle_projects/ts_forecasting/submissions/submission_v5.csv
# <class 'pandas.DataFrame'>
# RangeIndex: 1447107 entries, 0 to 1447106
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1447107 non-null  str
#  1   prediction  1447107 non-null  float64
# dtypes: float64(1), str(1)
# memory usage: 74.0 MB
#                                       id  prediction
# 0  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3647   -0.010542
# 1  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3648   -0.011377
# 2  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3649   -0.008052
# 3  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3650   -0.010372
# 4  W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3651   -0.007756

# %% [markdown]
# ## (Optional) Reload Models from Disk

# %%
# all_models = {}
# for h in HORIZONS:
#     for seed in SEEDS:
#         path = f"{MODEL_DIR}/lgb_v5_h{h}_seed{seed}.txt"
#         all_models[(h, seed)] = lgb.Booster(model_file=path)
# print(f'Reloaded {len(all_models)} models.')
