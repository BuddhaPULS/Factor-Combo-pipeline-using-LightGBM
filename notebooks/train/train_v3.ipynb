# %% [markdown]
# # Train v3
#
# Change from v2:
# - Config becomes more aggressive with avoiding overfitting
# - nummber of leaves:32->80
# - set min number of child samples: 200
# - set lambda_L2:10
# - number of boost round:1000->4200
# - stopping rounds:50->200

# %%
from pathlib import Path
import sys

# %%
PROJECT_ROOT = Path().resolve().parent.parent
sys.path.append(str(PROJECT_ROOT))

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import gc
from src.score import weighted_rmse_score as score

# %%
def set_cat(df, cat_features):
    for feat in cat_features:
        df[feat] = df[feat].astype('category')
    return df

# %% [markdown]
# ## Config

# %%
HORIZONS = [1, 3, 10, 25]

# Codes whose predictions are forced to 0 (both val and test)
ZERO_CODES = ['MLAAMU3K', 'EP12UF2K', '1HEMHZK2', 'SJZP0OVU', '83EG83KQ']

VERSION = "v3"

SPLIT_PERCENT = 0.8

params = {
    'objective': 'regression',
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'num_leaves': 80,
    'min_child_samples':200,
    'lambda_l2':10,
    'learning_rate': 0.01,
    'bagging_fraction': 0.7,   # pick 70% of data to train each tree
    'bagging_freq': 5,          # perform bagging every 5 iterations
    'feature_fraction': 0.8,   # pick 80% of features to train each tree
    'seed': 42,
    'verbosity': -1
}

# %% [markdown]
# ## Load & Prepare Data

# %%
df = pd.read_parquet(PROJECT_ROOT/"data"/"train.parquet")
cat_features = ['code', 'sub_category', 'horizon']
features = [feat for feat in df.columns if feat not in ['id', 'sub_code', 'ts_index', 'weight', 'y_target']]
df = set_cat(df, cat_features)

# %% [markdown]
# ## Time-based Train/Val Split
# Split is computed on the full dataset so each horizon uses the same boundary.

# %%
split_index = int(df['ts_index'].max() * SPLIT_PERCENT)
train_df = df[df['ts_index'] <= split_index]
val_df   = df[df['ts_index'] >  split_index]
print(f"Train size: {len(train_df):,} | Val size: {len(val_df):,} | Split ts_index: {split_index}")
del df
gc.collect()
# Out:
# Train size: 4,121,749 | Val size: 1,215,665 | Split ts_index: 2880
# 20

# %% [markdown]
# ## Train One Model per Horizon

# %%
models      = {}   # horizon -> trained booster
importances = {}   # horizon -> importance DataFrame

for h in HORIZONS:
    print(f"\n{'='*60}")
    print(f"  Training horizon = {h}")
    print(f"{'='*60}")

    # --- Subset by horizon ---
    h_train = train_df[train_df['horizon'] == h].copy()
    h_val   = val_df[val_df['horizon'] == h].copy()
    print(f"  Train rows: {len(h_train):,} | Val rows: {len(h_val):,}")

    # --- LightGBM Datasets ---
    # horizon is constant within each subset, but keep it as a feature
    # for consistency with v1; LGB will simply ignore it (zero split gain)
    dtrain = lgb.Dataset(
        h_train[features],
        label=h_train['y_target'],
        weight=h_train['weight'],
        categorical_feature=cat_features,
        free_raw_data=False
    )
    dval = lgb.Dataset(
        h_val[features],
        label=h_val['y_target'],
        weight=h_val['weight'],
        categorical_feature=cat_features,
        reference=dtrain,
        free_raw_data=False
    )

    # --- Train ---
    model = lgb.train(
        params,
        dtrain,
        valid_sets=[dtrain, dval],
        valid_names=['train', 'val'],
        num_boost_round=4200,
        callbacks=[
            lgb.early_stopping(stopping_rounds=200),
            lgb.log_evaluation(period=100)
        ]
    )
    models[h] = model

    # --- Save model ---
    model_path = PROJECT_ROOT/f"models/lgb_model_{VERSION}_horizon{h}.txt"
    model.save_model(model_path, num_iteration=model.best_iteration)
    print(f"  Model saved -> {model_path}  (best iteration: {model.best_iteration})")

    # --- Feature importance ---
    imp = pd.DataFrame({
        'feature': features,
        'importance': model.feature_importance(importance_type='gain')
    }).sort_values('importance', ascending=False)
    importances[h] = imp
    print(f"\n  Top-10 features (horizon={h}):")
    print(imp.head(10).to_string(index=False))
# Out:
# ============================================================
#   Training horizon = 1
# ============================================================
#   Train rows: 1,075,896 | Val rows: 318,757
# Training until validation scores don't improve for 200 rounds
# [100]	train's rmse: 0.000952292	val's rmse: 0.00109572
# [200]	train's rmse: 0.000945945	val's rmse: 0.00109547
# Early stopping, best iteration is:
# [54]	train's rmse: 0.000956131	val's rmse: 0.00109506
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon1.txt  (best iteration: 54)
#
#   Top-10 features (horizon=1):
#      feature    importance
#   feature_al 597992.294678
# sub_category 453719.358215
#   feature_by 391292.312866
#    feature_s 324545.879211
#   feature_cb 310786.383972
#   feature_cf 295148.835815
#   feature_bz 226457.973022
#   feature_ca 192230.463928
#    feature_v 177260.439514
#    feature_t 172563.089844
#
# ============================================================
#   Training horizon = 3
# ============================================================
#   Train rows: 1,069,360 | Val rows: 316,456
# Training until validation scores don't improve for 200 rounds
# [100]	train's rmse: 0.001132	val's rmse: 0.00190015
# [200]	train's rmse: 0.00112169	val's rmse: 0.00190775
# Early stopping, best iteration is:
# [93]	train's rmse: 0.00113294	val's rmse: 0.0018998
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon3.txt  (best iteration: 93)
#
#   Top-10 features (horizon=3):
#      feature   importance
# sub_category 2.740937e+06
#   feature_cg 1.756897e+06
#   feature_cf 1.649564e+06
#    feature_v 1.586208e+06
#   feature_ce 1.492813e+06
#   feature_as 1.292198e+06
#   feature_al 1.138569e+06
#   feature_cb 1.076063e+06
#   feature_bg 1.073791e+06
#   feature_bz 1.003721e+06
#
# ============================================================
#   Training horizon = 10
# ============================================================
#   Train rows: 1,033,203 | Val rows: 304,033
# Training until validation scores don't improve for 200 rounds
# [100]	train's rmse: 0.00257238	val's rmse: 0.00311957
# [200]	train's rmse: 0.002525	val's rmse: 0.00311513
# [300]	train's rmse: 0.00249212	val's rmse: 0.00311607
# [400]	train's rmse: 0.00246658	val's rmse: 0.00311688
# Early stopping, best iteration is:
# [242]	train's rmse: 0.00250994	val's rmse: 0.00311465
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon10.txt  (best iteration: 242)
#
#   Top-10 features (horizon=10):
#      feature   importance
#    feature_v 2.768101e+07
#   feature_cg 2.119084e+07
#   feature_ce 1.746164e+07
#   feature_cf 1.707077e+07
#   feature_bg 1.675857e+07
# sub_category 1.611078e+07
#    feature_l 1.607491e+07
#    feature_u 1.486594e+07
#   feature_aq 1.157350e+07
#    feature_m 1.049550e+07
#
# ============================================================
#   Training horizon = 25
# ============================================================
#   Train rows: 943,290 | Val rows: 276,419
# Training until validation scores don't improve for 200 rounds
# [100]	train's rmse: 0.00339528	val's rmse: 0.00410127
# [200]	train's rmse: 0.00329222	val's rmse: 0.00409162
# [300]	train's rmse: 0.00322602	val's rmse: 0.00409601
# Early stopping, best iteration is:
# [190]	train's rmse: 0.00330232	val's rmse: 0.00409112
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon25.txt  (best iteration: 190)
#
#   Top-10 features (horizon=25):
#      feature   importance
#    feature_v 7.878737e+07
# sub_category 7.169622e+07
#    feature_l 5.409603e+07
#   feature_bg 5.313528e+07
#   feature_cg 4.822274e+07
#    feature_m 4.402969e+07
#   feature_cf 3.605815e+07
#   feature_ce 3.144728e+07
#   feature_aq 3.127696e+07
#   feature_as 3.107889e+07

# %% [markdown]
# ## Train Scoring (per-horizon + overall)
# Zero-code override is applied before scoring.aa

# %%
# Collect all train predictions into a single aligned series
train_preds_series = pd.Series(index=train_df.index, dtype=float)

horizon_scores = {}

for h in HORIZONS:
    h_train  = train_df[train_df['horizon'] == h].copy()
    model  = models[h]

    preds  = model.predict(h_train[features], num_iteration=model.best_iteration)
    preds  = pd.Series(preds, index=h_train.index)

    # Apply zero-code override on val
    zero_mask = h_train['code'].isin(ZERO_CODES)
    preds[zero_mask] = 0.0

    train_preds_series[h_train.index] = preds

    h_score = score(h_train['y_target'], preds, h_train['weight'])
    horizon_scores[h] = h_score
    print(f"  Horizon {h:>2d} | Val Score: {h_score:.4f}  "
          f"(zero-coded rows: {zero_mask.sum():,})")

# Overall val score (all horizons together)
overall_val_score = score(train_df['y_target'], train_preds_series, train_df['weight'])
print(f"\n  Overall Val Score: {overall_val_score:.4f}")
# Out:
#   Horizon  1 | Val Score: 0.0978  (zero-coded rows: 220,566)
#   Horizon  3 | Val Score: 0.1465  (zero-coded rows: 219,510)
#   Horizon 10 | Val Score: 0.3067  (zero-coded rows: 211,972)
#   Horizon 25 | Val Score: 0.3650  (zero-coded rows: 191,418)
#
#   Overall Val Score: 0.3184

# %% [markdown]
# ## Validation Scoring (per-horizon + overall)
# Zero-code override is applied before scoring.

# %%
# Collect all val predictions into a single aligned series
val_preds_series = pd.Series(index=val_df.index, dtype=float)

horizon_scores = {}

for h in HORIZONS:
    h_val  = val_df[val_df['horizon'] == h].copy()
    model  = models[h]

    preds  = model.predict(h_val[features], num_iteration=model.best_iteration)
    preds  = pd.Series(preds, index=h_val.index)

    # Apply zero-code override on val
    zero_mask = h_val['code'].isin(ZERO_CODES)
    preds[zero_mask] = 0.0

    val_preds_series[h_val.index] = preds

    h_score = score(h_val['y_target'], preds, h_val['weight'])
    horizon_scores[h] = h_score
    print(f"  Horizon {h:>2d} | Val Score: {h_score:.4f}  "
          f"(zero-coded rows: {zero_mask.sum():,})")

# Overall val score (all horizons together)
overall_val_score = score(val_df['y_target'], val_preds_series, val_df['weight'])
print(f"\n  Overall Val Score: {overall_val_score:.4f}")
# Out:
#   Horizon  1 | Val Score: 0.0322  (zero-coded rows: 53,467)
#   Horizon  3 | Val Score: 0.0615  (zero-coded rows: 53,212)
#   Horizon 10 | Val Score: 0.0999  (zero-coded rows: 50,981)
#   Horizon 25 | Val Score: 0.1429  (zero-coded rows: 45,774)
#
#   Overall Val Score: 0.1189

# %%
del train_df, val_df, train_preds_series, val_preds_series
gc.collect()
# Out:
# 12

# %% [markdown]
# ## Test Predictions
# Each test row is predicted by the model matching its horizon.
# Zero-code override is applied after prediction.

# %%
df_test = pd.read_parquet(PROJECT_ROOT/"data"/"test.parquet")
df_test = set_cat(df_test, cat_features)

# %%
test_preds_series = pd.Series(index=df_test.index, dtype=float)

for h in HORIZONS:
    h_test    = df_test[df_test['horizon'] == h]
    model     = models[h]

    preds     = model.predict(h_test[features], num_iteration=model.best_iteration)
    preds     = pd.Series(preds, index=h_test.index)

    # Apply zero-code override on test
    zero_mask = h_test['code'].isin(ZERO_CODES)
    preds[zero_mask] = 0.0

    test_preds_series[h_test.index] = preds
    print(f"  Horizon {h:>2d} | Test rows: {len(h_test):,}  "
          f"(zero-coded rows: {zero_mask.sum():,})")

# Sanity check: no NaNs
assert test_preds_series.isna().sum() == 0, "Some test rows were not predicted!"
print(f"\n  Total test predictions: {len(test_preds_series):,}")
# Out:
#   Horizon  1 | Test rows: 379,617  (zero-coded rows: 69,005)
#   Horizon  3 | Test rows: 376,558  (zero-coded rows: 68,523)
#   Horizon 10 | Test rows: 362,057  (zero-coded rows: 65,675)
#   Horizon 25 | Test rows: 328,875  (zero-coded rows: 59,033)
#
#   Total test predictions: 1,447,107

# %% [markdown]
# ## Build & Save Submission

# %%
prediction_df = pd.DataFrame({
    'id':         df_test['id'].values,
    'prediction': test_preds_series.values
})

prediction_df.info(max_cols=10)
prediction_df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1447107 entries, 0 to 1447106
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1447107 non-null  str
#  1   prediction  1447107 non-null  float64
# dtypes: float64(1), str(1)
# memory usage: 73.8 MB
#                                        id  prediction
# 0   W2MW3G2L__495MGHFJ__PZ9S1Z4V__3__3647   -0.018474
# 1  W2MW3G2L__495MGHFJ__PZ9S1Z4V__10__3647   -0.035762
# 2  W2MW3G2L__495MGHFJ__PZ9S1Z4V__25__3647   -0.177384
# 3   W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3647   -0.005207
# 4  W2MW3G2L__495MGHFJ__PZ9S1Z4V__10__3648   -0.052517

# %%
prediction_df.to_csv(
    PROJECT_ROOT/f"submissions/submission_{VERSION}.csv",
    index=False
)
print("Submission saved.")
# Out:
# Submission saved.
