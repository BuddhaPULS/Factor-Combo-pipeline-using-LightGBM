# %% [markdown]
# # Train v2
# **Change from v1**:
# - Train model per horizon cause the distribution statistic of target for each horizon is signifcantly different.
# - Zero mask for several codes to avoid disaster cause their weight is high

# %%
from pathlib import Path
import sys

# %%
PROJECT_ROOT = Path().resolve().parent.parent
sys.path.append(str(PROJECT_ROOT))

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import gc
from src.score import weighted_rmse_score as score

# %%
def set_cat(df, cat_features):
    for feat in cat_features:
        df[feat] = df[feat].astype('category')
    return df

# %% [markdown]
# ## Config

# %%
HORIZONS = [1, 3, 10, 25]

# Codes whose predictions are forced to 0 (both val and test)
ZERO_CODES = ['MLAAMU3K', 'EP12UF2K', '1HEMHZK2', 'SJZP0OVU', '83EG83KQ']

VERSION = "v2"

SPLIT_PERCENT = 0.8

params = {
    'objective': 'regression',
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'num_leaves': 32,
    'learning_rate': 0.01,
    'bagging_fraction': 0.7,   # pick 70% of data to train each tree
    'bagging_freq': 5,          # perform bagging every 5 iterations
    'feature_fraction': 0.8,   # pick 80% of features to train each tree
    'seed': 42,
    'verbosity': -1
}

# %% [markdown]
# ## Load & Prepare Data

# %%
df = pd.read_parquet(PROJECT_ROOT / "data" / "train.parquet")
cat_features = ['code', 'sub_category', 'horizon']
features = [feat for feat in df.columns if feat not in ['id', 'sub_code', 'ts_index', 'weight', 'y_target']]
df = set_cat(df, cat_features)

# %% [markdown]
# ## Time-based Train/Val Split
# Split is computed on the full dataset so each horizon uses the same boundary.

# %%
split_index = int(df['ts_index'].max() * SPLIT_PERCENT)
train_df = df[df['ts_index'] <= split_index]
val_df   = df[df['ts_index'] >  split_index]
print(f"Train size: {len(train_df):,} | Val size: {len(val_df):,} | Split ts_index: {split_index}")
del df
gc.collect()
# Out:
# Train size: 4,121,749 | Val size: 1,215,665 | Split ts_index: 2880
# 20

# %% [markdown]
# ## Train One Model per Horizon

# %%
models      = {}   # horizon -> trained booster
importances = {}   # horizon -> importance DataFrame

for h in HORIZONS:
    print(f"\n{'='*60}")
    print(f"  Training horizon = {h}")
    print(f"{'='*60}")

    # --- Subset by horizon ---
    h_train = train_df[train_df['horizon'] == h].copy()
    h_val   = val_df[val_df['horizon'] == h].copy()
    print(f"  Train rows: {len(h_train):,} | Val rows: {len(h_val):,}")

    # --- LightGBM Datasets ---
    # horizon is constant within each subset, but keep it as a feature
    # for consistency with v1; LGB will simply ignore it (zero split gain)
    dtrain = lgb.Dataset(
        h_train[features],
        label=h_train['y_target'],
        weight=h_train['weight'],
        categorical_feature=cat_features,
        free_raw_data=False
    )
    dval = lgb.Dataset(
        h_val[features],
        label=h_val['y_target'],
        weight=h_val['weight'],
        categorical_feature=cat_features,
        reference=dtrain,
        free_raw_data=False
    )

    # --- Train ---
    model = lgb.train(
        params,
        dtrain,
        valid_sets=[dtrain, dval],
        valid_names=['train', 'val'],
        num_boost_round=1000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=50),
            lgb.log_evaluation(period=50)
        ]
    )
    models[h] = model

    # --- Save model ---
    model_path = PROJECT_ROOT / "models" / f"lgb_model_{VERSION}_horizon{h}.txt"
    model.save_model(model_path, num_iteration=model.best_iteration)
    print(f"  Model saved -> {model_path}  (best iteration: {model.best_iteration})")

    # --- Feature importance ---
    imp = pd.DataFrame({
        'feature': features,
        'importance': model.feature_importance(importance_type='gain')
    }).sort_values('importance', ascending=False)
    importances[h] = imp
    print(f"\n  Top-10 features (horizon={h}):")
    print(imp.head(10).to_string(index=False))
# Out:
# ============================================================
#   Training horizon = 1
# ============================================================
#   Train rows: 1,075,896 | Val rows: 318,757
# Training until validation scores don't improve for 50 rounds
# [50]	train's rmse: 0.000958425	val's rmse: 0.00109522
# [100]	train's rmse: 0.000955843	val's rmse: 0.00109484
# [150]	train's rmse: 0.000953609	val's rmse: 0.00109473
# [200]	train's rmse: 0.000951645	val's rmse: 0.00109458
# Early stopping, best iteration is:
# [187]	train's rmse: 0.000952147	val's rmse: 0.00109457
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon1.txt  (best iteration: 187)
#
#   Top-10 features (horizon=1):
#      feature    importance
#   feature_al 964314.498779
# sub_category 804205.690796
#   feature_by 746682.625671
#    feature_s 560723.971680
#   feature_bz 553918.168579
#   feature_cb 479002.308716
#    feature_w 406009.445374
#   feature_ca 398858.970032
#    feature_t 352559.159668
#   feature_am 336648.040649
#
# ============================================================
#   Training horizon = 3
# ============================================================
#   Train rows: 1,069,360 | Val rows: 316,456
# Training until validation scores don't improve for 50 rounds
# [50]	train's rmse: 0.00114166	val's rmse: 0.00190214
# [100]	train's rmse: 0.00113756	val's rmse: 0.00190112
# [150]	train's rmse: 0.00113402	val's rmse: 0.00190003
# [200]	train's rmse: 0.00113109	val's rmse: 0.00189943
# [250]	train's rmse: 0.00112817	val's rmse: 0.00189888
# [300]	train's rmse: 0.00112565	val's rmse: 0.00190033
# Early stopping, best iteration is:
# [274]	train's rmse: 0.00112692	val's rmse: 0.0018987
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon3.txt  (best iteration: 274)
#
#   Top-10 features (horizon=3):
#      feature   importance
# sub_category 3.740779e+06
#   feature_cg 2.713529e+06
#    feature_v 2.388486e+06
#   feature_by 2.267613e+06
#   feature_cf 1.883949e+06
#    feature_m 1.765307e+06
#   feature_ce 1.624484e+06
#   feature_cb 1.605116e+06
#   feature_aq 1.434134e+06
#   feature_ai 1.426485e+06
#
# ============================================================
#   Training horizon = 10
# ============================================================
#   Train rows: 1,033,203 | Val rows: 304,033
# Training until validation scores don't improve for 50 rounds
# [50]	train's rmse: 0.00262447	val's rmse: 0.00312441
# [100]	train's rmse: 0.00260355	val's rmse: 0.00312306
# [150]	train's rmse: 0.00258731	val's rmse: 0.00312041
# [200]	train's rmse: 0.00257527	val's rmse: 0.00311898
# [250]	train's rmse: 0.00256411	val's rmse: 0.00311801
# [300]	train's rmse: 0.00255386	val's rmse: 0.00311754
# [350]	train's rmse: 0.00254525	val's rmse: 0.00311729
# [400]	train's rmse: 0.00253705	val's rmse: 0.00311831
# Early stopping, best iteration is:
# [362]	train's rmse: 0.00254334	val's rmse: 0.0031169
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon10.txt  (best iteration: 362)
#
#   Top-10 features (horizon=10):
#      feature   importance
#    feature_v 2.175203e+07
#   feature_cg 1.715315e+07
# sub_category 1.612236e+07
#    feature_l 1.535161e+07
#   feature_am 1.278642e+07
#   feature_bg 1.269528e+07
#    feature_u 1.246956e+07
#   feature_cf 1.218438e+07
#   feature_ce 1.003243e+07
#   feature_as 9.583190e+06
#
# ============================================================
#   Training horizon = 25
# ============================================================
#   Train rows: 943,290 | Val rows: 276,419
# Training until validation scores don't improve for 50 rounds
# [50]	train's rmse: 0.003508	val's rmse: 0.00411761
# [100]	train's rmse: 0.00345893	val's rmse: 0.00411018
# [150]	train's rmse: 0.00342494	val's rmse: 0.00410487
# [200]	train's rmse: 0.00339578	val's rmse: 0.00410282
# Early stopping, best iteration is:
# [194]	train's rmse: 0.00339979	val's rmse: 0.00410208
#   Model saved -> /home/lingod/kaggle_projects/ts_forecasting/models/lgb_model_v2_horizon25.txt  (best iteration: 194)
#
#   Top-10 features (horizon=25):
#      feature   importance
# sub_category 6.928456e+07
#    feature_v 4.482107e+07
#    feature_l 4.008892e+07
#   feature_bp 3.469851e+07
#    feature_m 3.226898e+07
#   feature_cg 3.089045e+07
#   feature_ao 3.067372e+07
#   feature_as 2.786742e+07
#   feature_bg 2.662965e+07
#   feature_cf 2.280661e+07

# %% [markdown]
# ## Train Scoring (per-horizon + overall)
# Zero-code override is applied before scoring.

# %%
# Collect all train predictions into a single aligned series
train_preds_series = pd.Series(index=train_df.index, dtype=float)

horizon_scores = {}

for h in HORIZONS:
    h_train  = train_df[train_df['horizon'] == h].copy()
    model  = models[h]

    preds  = model.predict(h_train[features], num_iteration=model.best_iteration)
    preds  = pd.Series(preds, index=h_train.index)

    # Apply zero-code override on val
    zero_mask = h_train['code'].isin(ZERO_CODES)
    preds[zero_mask] = 0.0

    train_preds_series[h_train.index] = preds

    h_score = score(h_train['y_target'], preds, h_train['weight'])
    horizon_scores[h] = h_score
    print(f"  Horizon {h:>2d} | Val Score: {h_score:.4f}  "
          f"(zero-coded rows: {zero_mask.sum():,})")

# Overall val score (all horizons together)
overall_val_score = score(train_df['y_target'], train_preds_series, train_df['weight'])
print(f"\n  Overall Val Score: {overall_val_score:.4f}")
# Out:
#   Horizon  1 | Val Score: 0.1322  (zero-coded rows: 220,566)
#   Horizon  3 | Val Score: 0.1740  (zero-coded rows: 219,510)
#   Horizon 10 | Val Score: 0.2746  (zero-coded rows: 211,972)
#   Horizon 25 | Val Score: 0.3020  (zero-coded rows: 191,418)
#
#   Overall Val Score: 0.2741

# %% [markdown]
# ## Validation Scoring (per-horizon + overall)
# Zero-code override is applied before scoring.

# %%
# Collect all val predictions into a single aligned series
val_preds_series = pd.Series(index=val_df.index, dtype=float)

horizon_scores = {}

for h in HORIZONS:
    h_val  = val_df[val_df['horizon'] == h].copy()
    model  = models[h]

    preds  = model.predict(h_val[features], num_iteration=model.best_iteration)
    preds  = pd.Series(preds, index=h_val.index)

    # Apply zero-code override on val
    zero_mask = h_val['code'].isin(ZERO_CODES)
    preds[zero_mask] = 0.0

    val_preds_series[h_val.index] = preds

    h_score = score(h_val['y_target'], preds, h_val['weight'])
    horizon_scores[h] = h_score
    print(f"  Horizon {h:>2d} | Val Score: {h_score:.4f}  "
          f"(zero-coded rows: {zero_mask.sum():,})")

# Overall val score (all horizons together)
overall_val_score = score(val_df['y_target'], val_preds_series, val_df['weight'])
print(f"\n  Overall Val Score: {overall_val_score:.4f}")
# Out:
#   Horizon  1 | Val Score: 0.0424  (zero-coded rows: 53,467)
#   Horizon  3 | Val Score: 0.0680  (zero-coded rows: 53,212)
#   Horizon 10 | Val Score: 0.0877  (zero-coded rows: 50,981)
#   Horizon 25 | Val Score: 0.1272  (zero-coded rows: 45,774)
#
#   Overall Val Score: 0.1067

# %%
del train_df, val_df
gc.collect()
# Out:
# 1052

# %% [markdown]
# ## Test Predictions
# Each test row is predicted by the model matching its horizon.
# Zero-code override is applied after prediction.

# %%
df_test = pd.read_parquet(PROJECT_ROOT / "data" / "test.parquet")
df_test = set_cat(df_test, cat_features)

# %%
test_preds_series = pd.Series(index=df_test.index, dtype=float)

for h in HORIZONS:
    h_test    = df_test[df_test['horizon'] == h]
    model     = models[h]

    preds     = model.predict(h_test[features], num_iteration=model.best_iteration)
    preds     = pd.Series(preds, index=h_test.index)

    # Apply zero-code override on test
    zero_mask = h_test['code'].isin(ZERO_CODES)
    preds[zero_mask] = 0.0

    test_preds_series[h_test.index] = preds
    print(f"  Horizon {h:>2d} | Test rows: {len(h_test):,}  "
          f"(zero-coded rows: {zero_mask.sum():,})")

# Sanity check: no NaNs
assert test_preds_series.isna().sum() == 0, "Some test rows were not predicted!"
print(f"\n  Total test predictions: {len(test_preds_series):,}")
# Out:
#   Horizon  1 | Test rows: 379,617  (zero-coded rows: 69,005)
#   Horizon  3 | Test rows: 376,558  (zero-coded rows: 68,523)
#   Horizon 10 | Test rows: 362,057  (zero-coded rows: 65,675)
#   Horizon 25 | Test rows: 328,875  (zero-coded rows: 59,033)
#
#   Total test predictions: 1,447,107

# %% [markdown]
# ## Build & Save Submission

# %%
prediction_df = pd.DataFrame({
    'id':         df_test['id'].values,
    'prediction': test_preds_series.values
})

prediction_df.info(max_cols=10)
prediction_df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1447107 entries, 0 to 1447106
# Data columns (total 2 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1447107 non-null  str
#  1   prediction  1447107 non-null  float64
# dtypes: float64(1), str(1)
# memory usage: 73.8 MB
#                                        id  prediction
# 0   W2MW3G2L__495MGHFJ__PZ9S1Z4V__3__3647   -0.030540
# 1  W2MW3G2L__495MGHFJ__PZ9S1Z4V__10__3647   -0.042121
# 2  W2MW3G2L__495MGHFJ__PZ9S1Z4V__25__3647   -0.153536
# 3   W2MW3G2L__495MGHFJ__PZ9S1Z4V__1__3647   -0.000050
# 4  W2MW3G2L__495MGHFJ__PZ9S1Z4V__10__3648   -0.073165

# %%
prediction_df.to_csv(
    PROJECT_ROOT / "submissions" / f"submission_{VERSION}.csv",
    index=False
)
print("Submission saved.")
# Out:
# Submission saved.
